# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import math
from collections import Counter
from pathlib import Path
from IPython.display import clear_output
import random

data_path = '/home/szelesteya/projects/EMBED_Open_Data/'
image_root_path = '/media/szelesteya/F824D4D024D492CC/EMBED-images/'
image_training_path = image_root_path + 'training/'
image_positive_path = image_root_path + 'positive-full'
tables_path = data_path + 'tables/'
image_croped_pos_path = image_training_path + 'positive/' 

df_pos = pd.read_csv(data_path + 'positive_empirical_png.csv')
df_neg = pd.read_csv(data_path + 'negative_empirical_png.csv')

fix_resolution = [3328,4096]
crop_size = [224, 224]

# %%
def parse_ROI(roi_coords_row, side, width):
    roi_coords_array = roi_coords_row[2:-1].split('(')
    roi_rects = []
    
    for i in range(len(roi_coords_array)):
        roi_coords_str = roi_coords_array[i].split(')')[0].replace(" ","").split(',')
        if "" not in roi_coords_str:
            try:
                roi_coords = [eval(j.replace('[', '').replace(']','')) for j in roi_coords_str]
    
                x_min = roi_coords[1]
                y_min = roi_coords[0]
                x_max = roi_coords[3]
                y_max = roi_coords[2]

                if side == 'R':
                    x_min = width - roi_coords[3]
                    x_max = width - roi_coords[1]                 
                
                roi_rects.append([x_min, y_min, x_max, y_max])
            except SyntaxError:
                print(roi_coords_str)

    return roi_rects

def get_size_of_image(image_array):
    height = image_array.shape[0]
    width = image_array.shape[1]
    full_resolution = height * width
    diameter = math.sqrt( height ** 2 + width ** 2)
    dark_area = np.sum(image_array == 0)
    return [f'{height} x {width}', [height, width], full_resolution, diameter, dark_area]

def get_sizes_of_ROI(roi_coords_array):
    sizes = []

    for roi in roi_coords_array:
        size_str = f'{roi[2]-roi[0]} x {roi[3] - roi[1]}'
        height = roi[2] - roi[0]
        width = roi[3] - roi[1]
        full_resolution = height * width
        diameter = math.sqrt(height ** 2 + width ** 2)
        sizes.append([size_str,[height, width], height * width, diameter])

    return sizes

def generate_crop_path(index, roi_num):
    return image_croped_pos_path + f"{index}_{roi_num}_cropped"

# %%
df_pos_train = pd.DataFrame(columns=df_pos.columns).rename(columns={'Unnamed: 0': 'calc_finding_index'})

# %%
def crop_roi(calc_finding_row):    
    df_pos_train_index = len(df_pos_train)
    
    path = f"{image_croped_pos_path}{df_pos_train_index}_pos.png"

    image = Image.open(calc_finding_row['png_path'])
    image_array = np.array(image)
    side = calc_finding_row['side']
    width = image_array.shape[1]
    roi_coords = parse_ROI(calc_finding_row['ROI_coords'], side, width)
    image_sizes = get_size_of_image(image_array)
    image_size = image_sizes[1]
    roi_sizes = get_sizes_of_ROI(roi_coords)
    
    width_distortion = fix_resolution[0] / image_size[0]
    height_distortion = fix_resolution[1] / image_size[1]

    image_array_resize = np.array(image.resize(fix_resolution))

    for i,roi_coord in enumerate(roi_coords):
        crop_success = False
        flipped = False
        while not crop_success:
            
            x_min = int(roi_coord[0] * width_distortion)
            x_max = int(roi_coord[2] * width_distortion)
            y_min = int(roi_coord[1] * height_distortion)
            y_max = int(roi_coord[3] * height_distortion)
    
            x_center = round((x_min + x_max) / 2)
            y_center = round((y_min + y_max) / 2)
    
            croped_width = crop_size[0]
            croped_height = crop_size[1]
    
            x_offset = random.randint(-round(croped_width / 8), round(croped_width / 8))
            y_offset = random.randint(-round(croped_height / 8), round(croped_height / 8))
    
            x_crop = x_center - round(croped_width / 2) + x_offset
            y_crop = y_center - round(croped_height / 2) + y_offset
            
            fix_width = fix_resolution[0]
            fix_height = fix_resolution[1]
            
            if x_crop < 0:
                x_crop = 0
            elif x_crop + croped_width > fix_width:
                x_crop = fix_width - croped_width - 1
    
            if y_crop < 0:
                y_crop = 0
            elif y_crop + croped_height > fix_height:
                y_crop = fix_height - croped_height - 1
                
            roi_array = image_array_resize[(y_crop):(y_crop + croped_height),x_crop:(x_crop + croped_width)]
            plt.imshow(roi_array, cmap='grey')
            plt.axis('off')
    
            tissue_dist = np.sum(np.where((roi_array / 255) > 0.05, 1, 0)) / (crop_size[0] * crop_size[1])
            too_bright = np.sum(np.where((roi_array / 255) > 0.9, 1, 0) / (crop_size[0] * crop_size[1]))
            # print(roi_array / 255)
            # print(np.where((roi_array / 255) > 0.05, 1, 0))
            # print(tissue_dist_arr)
            print(too_bright)
            if too_bright > 0.5:
                print(f"Too much bright area on picture {path}")  
                return
            if (tissue_dist < 0.5):
                print(f"Too much dark area on picture {path} try to flip the roi horizontally")         
                x_min = int(fix_resolution[0] - roi_coord[2] * width_distortion)
                x_max = int(fix_resolution[0] - roi_coord[0] * width_distortion)
            else:
                print(f"Saving picture {path}")
                print(roi_array.shape)
                im = Image.fromarray(roi_array)
                im = im.save(path, mode='L')
                crop_success = True
                df_pos_train.loc[df_pos_train_index, :] = calc_finding_row
                df_pos_train.loc[df_pos_train_index, 'calc_finding_index'] = calc_finding_row['Unnamed: 0']
                df_pos_train.loc[df_pos_train_index, 'label_0'] = 1
                df_pos_train.loc[df_pos_train_index, 'crop_path'] = path
                df_pos_train_index += 1

            if flipped:
                print(f"Skipping picture {path}, probably roi not precise")
                return
            
            flipped = True

# %%
# print(df_pos)
with open('paths','w') as f:
    df_pos.drop_duplicates(subset=['empi_anon','acc_anon', 'side','study_date_anon','calc_find','ROI_coords','png_path'])[['png_path']].to_csv(f)

# %%
# df_pos_train = pd.read_csv('pos_training.csv')

# %%
crop_roi(df_pos.loc[30,:])
# Out:
# 0.0
# Too much dark or bright are on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/1_pos.png try to flip the roi horizontally

# %%
df_pos_train = pd.DataFrame(columns=df_pos.columns).rename(columns={'Unnamed: 0': 'calc_finding_index'})
for i in range(0,len(df_pos)):
    print(f"Cropping roi of image no {i}")
    crop_roi(df_pos.loc[i,:])

#df_pos_train
# Out:
# Cropping roi of image no 0
# 0.0003388073979591836
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/0_pos.png
# (224, 224)
# Cropping roi of image no 1
# 0.07270408163265306
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/1_pos.png
# (224, 224)
# Cropping roi of image no 2
# 0.2674585459183674
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/2_pos.png
# (224, 224)
# Cropping roi of image no 3
# 0.010881696428571428
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/3_pos.png try to flip the roi horizontally
# 0.08769132653061223
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/3_pos.png
# (224, 224)
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/3_pos.png, probably roi not precise
# Cropping roi of image no 4
# 0.14530851403061223
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/4_pos.png
# (224, 224)
# Cropping roi of image no 5
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/5_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/5_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/5_pos.png, probably roi not precise
# Cropping roi of image no 6
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/5_pos.png
# (224, 224)
# Cropping roi of image no 7
# 0.12254862882653059
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/6_pos.png
# (224, 224)
# Cropping roi of image no 8
# 0.006317761479591836
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/7_pos.png
# (224, 224)
# Cropping roi of image no 9
# 0.33573820153061223
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/8_pos.png
# (224, 224)
# Cropping roi of image no 10
# 0.07230548469387754
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/9_pos.png try to flip the roi horizontally
# 0.11575255102040816
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/9_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/9_pos.png, probably roi not precise
# Cropping roi of image no 11
# 0.0001594387755102041
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/9_pos.png
# (224, 224)
# Cropping roi of image no 12
# 0.04619738520408163
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/10_pos.png
# (224, 224)
# Cropping roi of image no 13
# 0.001295440051020408
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/11_pos.png
# (224, 224)
# Cropping roi of image no 14
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/12_pos.png
# (224, 224)
# 0.016462053571428572
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/12_pos.png
# (224, 224)
# Cropping roi of image no 15
# 0.07772640306122448
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/14_pos.png
# (224, 224)
# Cropping roi of image no 16
# 0.04611766581632653
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/15_pos.png
# (224, 224)
# Cropping roi of image no 17
# 0.18066406249999997
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/16_pos.png
# (224, 224)
# 0.02421476403061224
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/16_pos.png
# (224, 224)
# Cropping roi of image no 18
# 0.14385363520408162
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/18_pos.png
# (224, 224)
# 0.025111607142857147
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/18_pos.png
# (224, 224)
# Cropping roi of image no 19
# 0.04340720663265306
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/20_pos.png
# (224, 224)
# Cropping roi of image no 20
# 0.03770727040816326
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/21_pos.png
# (224, 224)
# Cropping roi of image no 21
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/22_pos.png
# (224, 224)
# Cropping roi of image no 22
# 3.985969387755102e-05
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/23_pos.png
# (224, 224)
# Cropping roi of image no 23
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/24_pos.png
# (224, 224)
# Cropping roi of image no 24
# 0.06210140306122448
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/25_pos.png
# (224, 224)
# Cropping roi of image no 25
# 0.14447146045918366
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/26_pos.png
# (224, 224)
# Cropping roi of image no 26
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/27_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/27_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/27_pos.png, probably roi not precise
# Cropping roi of image no 27
# 0.0013552295918367347
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/27_pos.png
# (224, 224)
# Cropping roi of image no 28
# 0.12472098214285714
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/28_pos.png
# (224, 224)
# Cropping roi of image no 29
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png, probably roi not precise
# Cropping roi of image no 30
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png, probably roi not precise
# Cropping roi of image no 31
# 0.12820870535714285
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/29_pos.png
# (224, 224)
# Cropping roi of image no 32
# 0.010403380102040817
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/30_pos.png
# (224, 224)
# Cropping roi of image no 33
# 0.004723373724489796
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/31_pos.png
# (224, 224)
# Cropping roi of image no 34
# 0.2259646045918367
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/32_pos.png
# (224, 224)
# Cropping roi of image no 35
# 0.7964764030612244
# Too much bright area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/33_pos.png
# Cropping roi of image no 36
# 0.0007174744897959184
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/33_pos.png
# (224, 224)
# Cropping roi of image no 37
# 0.25384646045918363
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/34_pos.png
# (224, 224)
# Cropping roi of image no 38
# 0.1385921556122449
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/35_pos.png
# (224, 224)
# 0.13221460459183676
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/35_pos.png
# (224, 224)
# Cropping roi of image no 39
# 0.22317442602040813
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/37_pos.png
# (224, 224)
# 0.11941964285714286
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/37_pos.png
# (224, 224)
# Cropping roi of image no 40
# 0.5436662946428572
# Too much bright area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/39_pos.png
# Cropping roi of image no 41
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/39_pos.png
# (224, 224)
# Cropping roi of image no 42
# 0.00011957908163265306
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/40_pos.png
# (224, 224)
# Cropping roi of image no 43
# 0.11322146045918366
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/41_pos.png
# (224, 224)
# Cropping roi of image no 44
# 0.002551020408163265
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png try to flip the roi horizontally
# 0.0004185267857142857
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png, probably roi not precise
# Cropping roi of image no 45
# 0.06499123086734694
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png
# (224, 224)
# 0.037248883928571425
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png
# (224, 224)
# 0.04751275510204081
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png try to flip the roi horizontally
# 0.02535076530612245
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/42_pos.png, probably roi not precise
# Cropping roi of image no 46
# 0.08133370535714285
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/44_pos.png
# (224, 224)
# 0.03910235969387755
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/44_pos.png
# (224, 224)
# 0.02485251913265306
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/44_pos.png try to flip the roi horizontally
# 0.04633689413265306
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/44_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/44_pos.png, probably roi not precise
# Cropping roi of image no 47
# 0.034438775510204085
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/46_pos.png
# (224, 224)
# Cropping roi of image no 48
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/47_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/47_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/47_pos.png, probably roi not precise
# Cropping roi of image no 49
# 0.16635443239795916
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/47_pos.png
# (224, 224)
# Cropping roi of image no 50
# 0.011539381377551021
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/48_pos.png
# (224, 224)
# Cropping roi of image no 51
# 0.04633689413265305
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/49_pos.png try to flip the roi horizontally
# 0.06724330357142856
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/49_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/49_pos.png, probably roi not precise
# Cropping roi of image no 52
# 0.026407047193877545
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/49_pos.png
# (224, 224)
# Cropping roi of image no 53
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png, probably roi not precise
# Cropping roi of image no 54
# 0.03310347576530612
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png try to flip the roi horizontally
# 0.035873724489795915
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png, probably roi not precise
# Cropping roi of image no 55
# 0.5654894770408163
# Too much bright area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png
# Cropping roi of image no 56
# 0.12111367984693877
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/50_pos.png
# (224, 224)
# Cropping roi of image no 57
# 0.33783083545918363
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/51_pos.png
# (224, 224)
# Cropping roi of image no 58
# 0.4515704719387755
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/52_pos.png
# (224, 224)
# 0.24918287627551017
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/52_pos.png
# (224, 224)
# Cropping roi of image no 59
# 0.15234375
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/54_pos.png
# (224, 224)
# Cropping roi of image no 60
# 0.02551020408163265
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/55_pos.png
# (224, 224)
# Cropping roi of image no 61
# 0.013950892857142856
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/56_pos.png
# (224, 224)
# Cropping roi of image no 62
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/57_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/57_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/57_pos.png, probably roi not precise
# Cropping roi of image no 63
# 0.22779815051020408
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/57_pos.png
# (224, 224)
# Cropping roi of image no 64
# 0.02632732780612245
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/58_pos.png
# (224, 224)
# Cropping roi of image no 65
# 7.971938775510203e-05
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png try to flip the roi horizontally
# 9.964923469387754e-05
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png, probably roi not precise
# Cropping roi of image no 66
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png, probably roi not precise
# Cropping roi of image no 67
# 0.11880181760204081
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/59_pos.png
# (224, 224)
# Cropping roi of image no 68
# 0.003846460459183673
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/60_pos.png
# (224, 224)
# Cropping roi of image no 69
# 1.0
# Too much bright area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/61_pos.png
# Cropping roi of image no 70
# 0.037408322704081634
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/61_pos.png
# (224, 224)
# Cropping roi of image no 71
# 0.23272082270408162
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/62_pos.png
# (224, 224)
# Cropping roi of image no 72
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/63_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/63_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/63_pos.png, probably roi not precise
# Cropping roi of image no 73
# 0.07045200892857141
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/63_pos.png
# (224, 224)
# Cropping roi of image no 74
# 0.07091039540816325
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/64_pos.png
# (224, 224)
# Cropping roi of image no 75
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/65_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/65_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/65_pos.png, probably roi not precise
# Cropping roi of image no 76
# 0.06060666454081633
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/65_pos.png
# (224, 224)
# Cropping roi of image no 77
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/66_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/66_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/66_pos.png, probably roi not precise
# Cropping roi of image no 78
# 0.02556999362244898
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/66_pos.png
# (224, 224)
# Cropping roi of image no 79
# 0.05534518494897959
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/67_pos.png
# (224, 224)
# Cropping roi of image no 80
# 0.033900669642857144
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/68_pos.png
# (224, 224)
# Cropping roi of image no 81
# 0.059091996173469385
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/69_pos.png
# (224, 224)
# Cropping roi of image no 82
# 0.0008370535714285714
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# 0.00023915816326530612
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png, probably roi not precise
# Cropping roi of image no 83
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png, probably roi not precise
# Cropping roi of image no 84
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png, probably roi not precise
# Cropping roi of image no 85
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png, probably roi not precise
# Cropping roi of image no 86
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png, probably roi not precise
# Cropping roi of image no 87
# 0.2971739477040816
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/70_pos.png
# (224, 224)
# Cropping roi of image no 88
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/71_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/71_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/71_pos.png, probably roi not precise
# Cropping roi of image no 89
# 0.10140306122448978
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/71_pos.png
# (224, 224)
# Cropping roi of image no 90
# 0.0017139668367346938
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/72_pos.png
# (224, 224)
# Cropping roi of image no 91
# 0.00031887755102040814
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/73_pos.png
# (224, 224)
# Cropping roi of image no 92
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/74_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/74_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/74_pos.png, probably roi not precise
# Cropping roi of image no 93
# 0.2559390943877551
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/74_pos.png
# (224, 224)
# Cropping roi of image no 94
# 0.05026307397959184
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/75_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/75_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/75_pos.png, probably roi not precise
# Cropping roi of image no 95
# 0.3152702487244897
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/75_pos.png
# (224, 224)
# Cropping roi of image no 96
# 0.002770248724489796
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/76_pos.png
# (224, 224)
# Cropping roi of image no 97
# 0.08595742984693877
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/77_pos.png
# (224, 224)
# Cropping roi of image no 98
# 0.01397082270408163
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/78_pos.png
# (224, 224)
# Cropping roi of image no 99
# 0.04270966198979592
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/79_pos.png
# (224, 224)
# 0.027124521683673467
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/79_pos.png
# (224, 224)
# Cropping roi of image no 100
# 0.12105389030612243
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/81_pos.png
# (224, 224)
# Cropping roi of image no 101
# 0.04827008928571428
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/82_pos.png try to flip the roi horizontally
# 0.040138711734693876
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/82_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/82_pos.png, probably roi not precise
# Cropping roi of image no 102
# 0.34713807397959184
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/82_pos.png
# (224, 224)
# Cropping roi of image no 103
# 0.0031090561224489796
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/83_pos.png
# (224, 224)
# Cropping roi of image no 104
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/84_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/84_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/84_pos.png, probably roi not precise
# Cropping roi of image no 105
# 0.024135044642857144
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/84_pos.png
# (224, 224)
# Cropping roi of image no 106
# 0.1346061862244898
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/85_pos.png
# (224, 224)
# Cropping roi of image no 107
# 0.08775111607142856
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png try to flip the roi horizontally
# 0.08304767219387756
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png, probably roi not precise
# Cropping roi of image no 108
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png, probably roi not precise
# Cropping roi of image no 109
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png, probably roi not precise
# Cropping roi of image no 110
# 0.05865353954081632
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/86_pos.png
# (224, 224)
# Cropping roi of image no 111
# 0.1635642538265306
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/87_pos.png try to flip the roi horizontally
# 0.19136639030612246
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/87_pos.png
# (224, 224)
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/87_pos.png, probably roi not precise
# Cropping roi of image no 112
# 0.16204958545918366
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/88_pos.png
# (224, 224)
# Cropping roi of image no 113
# 0.050741390306122444
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/89_pos.png
# (224, 224)
# Cropping roi of image no 114
# 0.08244977678571427
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/90_pos.png
# (224, 224)
# Cropping roi of image no 115
# 0.014010682397959183
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/91_pos.png
# (224, 224)
# Cropping roi of image no 116
# 0.19457509566326528
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/92_pos.png
# (224, 224)
# Cropping roi of image no 117
# 0.16739078443877548
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/93_pos.png
# (224, 224)
# Cropping roi of image no 118
# 0.0500438456632653
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/94_pos.png
# (224, 224)
# Cropping roi of image no 119
# 0.03421954719387755
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/95_pos.png
# (224, 224)
# Cropping roi of image no 120
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/96_pos.png
# (224, 224)
# Cropping roi of image no 121
# 0.21063855229591835
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/97_pos.png
# (224, 224)
# Cropping roi of image no 122
# 0.013552295918367346
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/98_pos.png
# (224, 224)
# Cropping roi of image no 123
# 0.0025510204081632647
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/99_pos.png
# (224, 224)
# Cropping roi of image no 124
# 0.0024912308673469387
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/100_pos.png
# (224, 224)
# Cropping roi of image no 125
# 0.021165497448979588
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/101_pos.png
# (224, 224)
# Cropping roi of image no 126
# 0.024912308673469385
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/102_pos.png
# (224, 224)
# Cropping roi of image no 127
# 0.001753826530612245
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/103_pos.png
# (224, 224)
# Cropping roi of image no 128
# 0.16352439413265307
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/104_pos.png
# (224, 224)
# Cropping roi of image no 129
# 0.18353396045918366
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/105_pos.png
# (224, 224)
# Cropping roi of image no 130
# 0.06084582270408162
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/106_pos.png
# (224, 224)
# Cropping roi of image no 131
# 0.06953523596938777
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/107_pos.png
# (224, 224)
# Cropping roi of image no 132
# 0.01357222576530612
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/108_pos.png
# (224, 224)
# Cropping roi of image no 133
# 0.03659119897959183
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/109_pos.png
# (224, 224)
# Cropping roi of image no 134
# 0.018315529336734693
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/110_pos.png
# (224, 224)
# Cropping roi of image no 135
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/111_pos.png
# (224, 224)
# Cropping roi of image no 136
# 0.0866549744897959
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/112_pos.png
# (224, 224)
# Cropping roi of image no 137
# 0.11639030612244897
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/113_pos.png try to flip the roi horizontally
# 0.08159279336734694
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/113_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/113_pos.png, probably roi not precise
# Cropping roi of image no 138
# 0.014748086734693877
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/113_pos.png
# (224, 224)
# Cropping roi of image no 139
# 0.16649394132653061
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/114_pos.png try to flip the roi horizontally
# 0.14995216836734696
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/114_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/114_pos.png, probably roi not precise
# Cropping roi of image no 140
# 0.07280373086734693
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/114_pos.png
# (224, 224)
# Cropping roi of image no 141
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/115_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/115_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/115_pos.png, probably roi not precise
# Cropping roi of image no 142
# 0.03611288265306122
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/115_pos.png
# (224, 224)
# Cropping roi of image no 143
# 0.08436304209183673
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/116_pos.png
# (224, 224)
# Cropping roi of image no 144
# 0.035913584183673464
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/117_pos.png
# (224, 224)
# Cropping roi of image no 145
# 0.08296795280612244
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/118_pos.png
# (224, 224)
# Cropping roi of image no 146
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/119_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/119_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/119_pos.png, probably roi not precise
# Cropping roi of image no 147
# 0.00015943877551020407
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/119_pos.png
# (224, 224)
# Cropping roi of image no 148
# 0.14662388392857142
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/120_pos.png
# (224, 224)
# Cropping roi of image no 149
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png, probably roi not precise
# Cropping roi of image no 150
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png, probably roi not precise
# Cropping roi of image no 151
# 0.018714126275510203
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/121_pos.png
# (224, 224)
# Cropping roi of image no 152
# 0.05014349489795918
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/122_pos.png
# (224, 224)
# Cropping roi of image no 153
# 0.053830516581632654
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/123_pos.png
# (224, 224)
# Cropping roi of image no 154
# 0.00571986607142857
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/124_pos.png
# (224, 224)
# Cropping roi of image no 155
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/125_pos.png
# (224, 224)
# Cropping roi of image no 156
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png, probably roi not precise
# Cropping roi of image no 157
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png, probably roi not precise
# Cropping roi of image no 158
# 0.02796157525510204
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/126_pos.png
# (224, 224)
# Cropping roi of image no 159
# 0.11541374362244897
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/127_pos.png try to flip the roi horizontally
# 0.1351044323979592
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/127_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/127_pos.png, probably roi not precise
# Cropping roi of image no 160
# 0.05839445153061224
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/127_pos.png
# (224, 224)
# Cropping roi of image no 161
# 0.05339205994897959
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/128_pos.png
# (224, 224)
# Cropping roi of image no 162
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png, probably roi not precise
# Cropping roi of image no 163
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png, probably roi not precise
# Cropping roi of image no 164
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png, probably roi not precise
# Cropping roi of image no 165
# 0.00023915816326530612
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/129_pos.png
# (224, 224)
# Cropping roi of image no 166
# 0.12209024234693877
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/130_pos.png
# (224, 224)
# Cropping roi of image no 167
# 0.027503188775510206
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/131_pos.png
# (224, 224)
# Cropping roi of image no 168
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png, probably roi not precise
# Cropping roi of image no 169
# 0.1489158163265306
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png try to flip the roi horizontally
# 0.1499920280612245
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png, probably roi not precise
# Cropping roi of image no 170
# 0.00013950892857142856
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/132_pos.png
# (224, 224)
# Cropping roi of image no 171
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/133_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/133_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/133_pos.png, probably roi not precise
# Cropping roi of image no 172
# 0.002889827806122449
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/133_pos.png
# (224, 224)
# Cropping roi of image no 173
# 0.1395687181122449
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/134_pos.png
# (224, 224)
# Cropping roi of image no 174
# 0.08904655612244897
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/135_pos.png
# (224, 224)
# Cropping roi of image no 175
# 0.08613679846938775
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/136_pos.png
# (224, 224)
# Cropping roi of image no 176
# 0.2820272640306123
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/137_pos.png
# (224, 224)
# Cropping roi of image no 177
# 0.0002192283163265306
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/138_pos.png
# (224, 224)
# Cropping roi of image no 178
# 0.04474250637755102
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/139_pos.png try to flip the roi horizontally
# 0.03788663903061225
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/139_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/139_pos.png, probably roi not precise
# Cropping roi of image no 179
# 0.03952088647959184
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/139_pos.png
# (224, 224)
# Cropping roi of image no 180
# 0.20346380739795913
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/140_pos.png
# (224, 224)
# Cropping roi of image no 181
# 0.12581712372448978
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/141_pos.png
# (224, 224)
# Cropping roi of image no 182
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/142_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/142_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/142_pos.png, probably roi not precise
# Cropping roi of image no 183
# 0.003049266581632653
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/142_pos.png
# (224, 224)
# Cropping roi of image no 184
# 0.06712372448979592
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/143_pos.png
# (224, 224)
# Cropping roi of image no 185
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/144_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/144_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/144_pos.png, probably roi not precise
# Cropping roi of image no 186
# 0.0004982461734693877
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/144_pos.png
# (224, 224)
# Cropping roi of image no 187
# 0.0022122130102040813
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/145_pos.png
# (224, 224)
# Cropping roi of image no 188
# 0.0006576849489795919
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/146_pos.png
# (224, 224)
# Cropping roi of image no 189
# 0.010084502551020409
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/147_pos.png
# (224, 224)
# Cropping roi of image no 190
# 0.010204081632653062
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png try to flip the roi horizontally
# 0.02684550382653061
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png, probably roi not precise
# Cropping roi of image no 191
# 0.03202726403061224
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png
# (224, 224)
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/148_pos.png, probably roi not precise
# Cropping roi of image no 192
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/149_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/149_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/149_pos.png, probably roi not precise
# Cropping roi of image no 193
# 0.005181760204081632
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/149_pos.png
# (224, 224)
# Cropping roi of image no 194
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/150_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/150_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/150_pos.png, probably roi not precise
# Cropping roi of image no 195
# 0.00015943877551020407
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/150_pos.png
# (224, 224)
# Cropping roi of image no 196
# 0.02375637755102041
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/151_pos.png
# (224, 224)
# Cropping roi of image no 197
# 0.02289939413265306
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/152_pos.png
# (224, 224)
# Cropping roi of image no 198
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/153_pos.png try to flip the roi horizontally
# 0.0
# ...
# Cropping roi of image no 536
# 0.07260443239795919
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/394_pos.png
# (224, 224)
# Cropping roi of image no 537
# 0.06999362244897958
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/395_pos.png
# (224, 224)
# Cropping roi of image no 538
# 0.012197066326530613
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/396_pos.png
# (224, 224)
# Cropping roi of image no 539
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/397_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/397_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/397_pos.png, probably roi not precise
# Cropping roi of image no 540
# 0.0031887755102040813
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/397_pos.png
# (224, 224)
# Cropping roi of image no 541
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/398_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/398_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/398_pos.png, probably roi not precise
# Cropping roi of image no 542
# 0.052076690051020405
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/398_pos.png
# (224, 224)
# Cropping roi of image no 543
# 0.0975765306122449
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/399_pos.png
# (224, 224)
# Cropping roi of image no 544
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/400_pos.png
# (224, 224)
# Cropping roi of image no 545
# 0.06401466836734694
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/401_pos.png
# (224, 224)
# Cropping roi of image no 546
# 0.045420121173469385
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/402_pos.png
# (224, 224)
# Cropping roi of image no 547
# 0.05078124999999999
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/403_pos.png
# (224, 224)
# 0.06997369260204082
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/403_pos.png
# (224, 224)
# Cropping roi of image no 548
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/405_pos.png try to flip the roi horizontally
# 0.00470344387755102
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/405_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/405_pos.png, probably roi not precise
# Cropping roi of image no 549
# 0.18991151147959184
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/405_pos.png
# (224, 224)
# Cropping roi of image no 550
# 0.0034080038265306123
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/406_pos.png
# (224, 224)
# Cropping roi of image no 551
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png, probably roi not precise
# Cropping roi of image no 552
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png, probably roi not precise
# Cropping roi of image no 553
# 0.0889469068877551
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/407_pos.png
# (224, 224)
# Cropping roi of image no 554
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png, probably roi not precise
# Cropping roi of image no 555
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png, probably roi not precise
# Cropping roi of image no 556
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png, probably roi not precise
# Cropping roi of image no 557
# 0.001793686224489796
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/408_pos.png
# (224, 224)
# Cropping roi of image no 558
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/409_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/409_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/409_pos.png, probably roi not precise
# Cropping roi of image no 559
# 0.05943080357142857
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/409_pos.png
# (224, 224)
# Cropping roi of image no 560
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png, probably roi not precise
# Cropping roi of image no 561
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png, probably roi not precise
# Cropping roi of image no 562
# 0.0058793048469387744
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/410_pos.png
# (224, 224)
# Cropping roi of image no 563
# 0.03742825255102041
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/411_pos.png
# (224, 224)
# Cropping roi of image no 564
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/412_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/412_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/412_pos.png, probably roi not precise
# Cropping roi of image no 565
# 0.48353794642857134
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/412_pos.png
# (224, 224)
# Cropping roi of image no 566
# 0.4805484693877551
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/413_pos.png
# (224, 224)
# Cropping roi of image no 567
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/414_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/414_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/414_pos.png, probably roi not precise
# Cropping roi of image no 568
# 0.018116230867346938
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/414_pos.png
# (224, 224)
# 0.013691804846938774
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/414_pos.png
# (224, 224)
# Cropping roi of image no 569
# 0.015206473214285714
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/416_pos.png try to flip the roi horizontally
# 0.0204280931122449
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/416_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/416_pos.png, probably roi not precise
# Cropping roi of image no 570
# 0.022460937499999997
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/416_pos.png
# (224, 224)
# Cropping roi of image no 571
# 0.09992825255102042
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/417_pos.png
# (224, 224)
# Cropping roi of image no 572
# 0.049485809948979595
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/418_pos.png
# (224, 224)
# Cropping roi of image no 573
# 0.06214126275510204
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/419_pos.png try to flip the roi horizontally
# 0.06851881377551021
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/419_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/419_pos.png, probably roi not precise
# Cropping roi of image no 574
# 0.009526466836734693
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/419_pos.png
# (224, 224)
# Cropping roi of image no 575
# 0.01638233418367347
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/420_pos.png
# (224, 224)
# Cropping roi of image no 576
# 0.1484972895408163
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/421_pos.png
# (224, 224)
# Cropping roi of image no 577
# 9.964923469387754e-05
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/422_pos.png
# (224, 224)
# Cropping roi of image no 578
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png, probably roi not precise
# Cropping roi of image no 579
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png, probably roi not precise
# Cropping roi of image no 580
# 0.00039859693877551016
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/423_pos.png
# (224, 224)
# Cropping roi of image no 581
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/424_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/424_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/424_pos.png, probably roi not precise
# Cropping roi of image no 582
# 0.017498405612244895
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/424_pos.png
# (224, 224)
# Cropping roi of image no 583
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/425_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/425_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/425_pos.png, probably roi not precise
# Cropping roi of image no 584
# 0.2200255102040816
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/425_pos.png
# (224, 224)
# Cropping roi of image no 585
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/426_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/426_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/426_pos.png, probably roi not precise
# Cropping roi of image no 586
# 0.01891342474489796
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/426_pos.png
# (224, 224)
# Cropping roi of image no 587
# 0.06556919642857142
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/427_pos.png try to flip the roi horizontally
# 0.06586814413265304
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/427_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/427_pos.png, probably roi not precise
# Cropping roi of image no 588
# 0.05434869260204081
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/427_pos.png
# (224, 224)
# Cropping roi of image no 589
# 0.0
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/428_pos.png
# (224, 224)
# Cropping roi of image no 590
# 0.0014349489795918366
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/429_pos.png
# (224, 224)
# Cropping roi of image no 591
# 0.09510522959183672
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/430_pos.png
# (224, 224)
# Cropping roi of image no 592
# 0.19421635841836732
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/431_pos.png
# (224, 224)
# Cropping roi of image no 593
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/432_pos.png try to flip the roi horizontally
# 0.0
# Too much dark area on picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/432_pos.png try to flip the roi horizontally
# Skipping picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/432_pos.png, probably roi not precise
# Cropping roi of image no 594
# 0.15005181760204078
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/432_pos.png
# (224, 224)
# Cropping roi of image no 595
# 0.14287707270408162
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/433_pos.png
# (224, 224)
# Cropping roi of image no 596
# 0.05881297831632653
# Saving picture /media/szelesteya/F824D4D024D492CC/EMBED-images/training/positive/434_pos.png
# (224, 224)

# %%
import gc
# Out:
# 32962

# %%
df_pos_train['training_path'] = df_pos_train['crop_path'].apply(lambda x: f"{x.replace('training/positive','training/all')}.png")

# %%
with open('pos_training.csv','w') as f:
    df_pos_train.to_csv(f)
